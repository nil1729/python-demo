# %%
# Object Oriented Programming

# %%
mylist = [1, 2, 3]
mylist.append(4) #Built-in Objects and Methods

# %%
type(mylist)
# Out:
# list

# %%
# (Attribute and Class Keyword)

# %%
class MySampleClass():
    pass

# %%
sample_class = MySampleClass()

# %%
type(sample_class)
# Out:
# __main__.MySampleClass

# %%
class Dog():
    def __init__(self, breed):
        
        # Attributes
        # We take in the arguments
        # Assign it using self.attribute_name
        self.breed = breed

# %%
my_dog = Dog()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b867e62b00ec> in <module>
# ----> 1 my_dog = Dog()
#
# TypeError: __init__() missing 1 required positional argument: 'breed'

# %%
my_dog = Dog('lab')

# %%
my_dog.breed
# Out:
# 'lab'

# %%
my_new_dog = Dog(breed='Java')

# %%
my_new_dog.breed
# Out:
# 'Java'

# %%
# (Class Object Attributes and Methods)

# %%
class Television():
    
    # CLASS OBJECT ATTRIBUTES
    # SAME FOR ANY INSTANCE OF A CLASS
    
    display_type = 'LED'
    
    # Attributes
    # We take in the arguments
    # Assign it using self.attribute_name
    
    def __init__(self, model):
        self.model = model
    
    
    # OPERATIONS/Actions -----> Methods
    
    def features(self):
        print(f'Display Type: {self.display_type}\nModel: {self.model}')

# %%
tv_1 = Television('MI')

# %%
tv_2 = Television('Samsung')

# %%
tv_1.display_type
# Out:
# 'LED'

# %%
tv_2.display_type
# Out:
# 'LED'

# %%
tv_1.features()
# Out:
# Display Type: LED
# Model: MI

# %%
tv_2.features()
# Out:
# Display Type: LED
# Model: Samsung

# %%
class Circle():
    
    # CLASS OBJECT ATTRIBUTE
    pi = 3.14
    
    
    def __init__(self, radius=1):
        
        self.radius = radius
        # self.area = radius * radius * self.pi
        self.area = radius * radius * Circle.pi
        
    # METHODS    
    def get_circumference(self):
        return self.radius * self.pi * 2

# %%
my_circle = Circle(45)

# %%
my_circle.pi
# Out:
# 3.14

# %%
my_circle.radius
# Out:
# 45

# %%
my_circle.get_circumference()
# Out:
# 282.6

# %%
my_circle.area
# Out:
# 6358.5

# %%
# Inheritence

# %%
class Animal():
    
    def __init__(self):
        print("Animal Created")
    
    def who_am_i(self):
        print("I am an animal")
        
    def eat(self):
        print("I am eating")

# %%
myanimal = Animal()
# Out:
# Animal Created

# %%
myanimal.eat()
# Out:
# I am eating

# %%
myanimal.who_am_i()
# Out:
# I am an animal

# %%
class Dog(Animal): # inherit class Animal
    
    def __init__(self):
        Animal.__init__(self)
        print("Dog Created")
    
    def who_am_i(self):
        print("I am a Dog")

# %%
mydog = Dog()
# Out:
# Animal Created
# Dog Created

# %%
mydog.who_am_i()
# Out:
# I am a Dog

# %%
# Special Methods

# %%
my_list = [1, 2, 3]
len(my_list)
# Out:
# 3

# %%
class Book():
    
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages
    def __str__(self):
        return f"{self.title} by {self.author}, pages: {self.pages}"
    def __len__(self):
        return self.pages
    def __del__(self):
        print(f"A book named {self.title} has been deleted")

# %%
mybook = Book('Python3', 'Guido van Rossum', 1000)

# %%
print(mybook)
# Out:
# Python3 by Guido van Rossum, pages: 1000

# %%
str(mybook)
# Out:
# 'Python3 by Guido van Rossum, pages: 1000'

# %%
len(mybook)
# Out:
# 1000

# %%
del mybook
# Out:
# A book named Python3 has been deleted

# %%
mybook
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-2909dc260504> in <module>
# ----> 1 mybook
#
# NameError: name 'mybook' is not defined
